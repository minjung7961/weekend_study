# %% [markdown]
# # 주택도시보증공사_전국 신규 민간아파트 분양가격 동향

# %% [markdown]
# # contents - 분양 가격 예측
# * 데이터 전처리
# >

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
plt.rc('font',family='Malgun Gothic')
plt.rc('axes',unicode_minus=False)

# %%
df_house = pd.read_csv("주택도시보증공사_전국 신규 민간아파트 분양가격 동향_20210315.csv",encoding='cp949')
df_house.head()
# Out:
#   지역명               규모구분    연도   월 분양가격(㎡)
# 0  서울               모든면적  2015  10    5841
# 1  서울         전용면적 60㎡이하  2015  10    5652
# 2  서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 3  서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 4  서울        전용면적 102㎡초과  2015  10    5879

# %%
df_house.tail()
# Out:
#      지역명               규모구분    연도  월 분양가격(㎡)
# 5605  제주               모든면적  2021  3    7199
# 5606  제주         전용면적 60㎡이하  2021  3    4686
# 5607  제주   전용면적 60㎡초과 85㎡이하  2021  3    7180
# 5608  제주  전용면적 85㎡초과 102㎡이하  2021  3     NaN
# 5609  제주        전용면적 102㎡초과  2021  3    7727

# %%
df_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5610 entries, 0 to 5609
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      5610 non-null   object
#  1   규모구분     5610 non-null   object
#  2   연도       5610 non-null   int64
#  3   월        5610 non-null   int64
#  4   분양가격(㎡)  5170 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 219.3+ KB

# %% [markdown]
# #### 널값 확인

# %%
df_house.isnull().sum()
# Out:
# 지역명          0
# 규모구분         0
# 연도           0
# 월            0
# 분양가격(㎡)    440
# dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df_house.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 컬럼 내용 확인

# %%
cols = df_house.columns
for i in cols:
    print(i,':\n')
    print(df_house[i].value_counts(),'\n')
# Out:
# 지역명 :
#
# 울산    330
# 대구    330
# 서울    330
# 충남    330
# 대전    330
# 광주    330
# 경남    330
# 제주    330
# 세종    330
# 강원    330
# 경북    330
# 부산    330
# 전남    330
# 전북    330
# 인천    330
# 경기    330
# 충북    330
# Name: 지역명, dtype: int64
#
# 규모구분 :
#
# 전용면적 60㎡이하           1122
# 전용면적 102㎡초과          1122
# 전용면적 60㎡초과 85㎡이하     1122
# 전용면적 85㎡초과 102㎡이하    1122
# 모든면적                 1122
# Name: 규모구분, dtype: int64
#
# 연도 :
#
# 2019    1020
# 2018    1020
# 2017    1020
# 2020    1020
# 2016    1020
# 2015     255
# 2021     255
# Name: 연도, dtype: int64
#
# 월 :
#
# 11    510
# 3     510
# 10    510
# 2     510
# 1     510
# 12    510
# 7     425
# 6     425
# 9     425
# 5     425
# 8     425
# 4     425
# Name: 월, dtype: int64
#
# 분양가격(㎡) :
#
# 3395    18
# 2667    17
# 2221    17
#         16
# 2743    16
#         ..
# 7067     1
# 2005     1
# 4346     1
# 2195     1
# 2868     1
# Name: 분양가격(㎡), Length: 2114, dtype: int64

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# #### 위에서 연도값의 2015년 2021년이 상대적으로 작은 것 확인가능 전처리해줌

# %%
df_house = df_house[df_house['연도'] != 2015].copy()
df_house['연도'].value_counts()
# Out:
# 2019    1020
# 2018    1020
# 2017    1020
# 2020    1020
# 2016    1020
# Name: 연도, dtype: int64

# %% [markdown]
# #### 분양가격 평당 분양가격으로 변경해줌

# %%
#### pd.to_numeric 을 통해 데이터의 타입을 변경
df_house['분양가격'] = pd.to_numeric(df_house['분양가격(㎡)'], errors='coerce')
df_house.head()
# Out:
#     지역명               규모구분    연도  월 분양가격(㎡)    분양가격
# 255  서울               모든면적  2016  1    6108  6108.0
# 256  서울         전용면적 60㎡이하  2016  1    6427  6427.0
# 257  서울   전용면적 60㎡초과 85㎡이하  2016  1    6036  6036.0
# 258  서울  전용면적 85㎡초과 102㎡이하  2016  1    6513  6513.0
# 259  서울        전용면적 102㎡초과  2016  1    6551  6551.0

# %%
#### 분양가격 평당 분양가격으로 변경해줌
df_house['평당분양가격'] = df_house['분양가격'] * 3.3

# %%
df_house['평당분양가격']
# Out:
# 255     20156.4
# 256     21209.1
# 257     19918.8
# 258     21492.9
# 259     21618.3
#          ...
# 5350    15338.4
# 5351    14397.9
# 5352    15378.0
# 5353        NaN
# 5354        NaN
# Name: 평당분양가격, Length: 5100, dtype: float64

# %%
df_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5100 entries, 255 to 5354
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지역명      5100 non-null   object
#  1   규모구분     5100 non-null   object
#  2   연도       5100 non-null   int64
#  3   월        5100 non-null   int64
#  4   분양가격(㎡)  4676 non-null   object
#  5   분양가격     4596 non-null   float64
#  6   평당분양가격   4596 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 318.8+ KB

# %% [markdown]
# #### 이제 규모구분 컬럼내용 변경필요

# %%
df_house['규모구분'].value_counts()
# Out:
# 전용면적 60㎡초과 85㎡이하     1020
# 전용면적 60㎡이하           1020
# 전용면적 85㎡초과 102㎡이하    1020
# 전용면적 102㎡초과          1020
# 모든면적                 1020
# Name: 규모구분, dtype: int64

# %%
df_house['전용면적'] = df_house['규모구분'].str.replace('전용면적',"")
df_house['전용면적'] = df_house['전용면적'].str.replace('초과','~')
df_house['전용면적'] = df_house['전용면적'].str.replace('이하','')
df_house['전용면적'] = df_house['전용면적'].str.replace(' ','').str.strip()
df_house['전용면적']
# Out:
# 255         모든면적
# 256          60㎡
# 257      60㎡~85㎡
# 258     85㎡~102㎡
# 259        102㎡~
#           ...
# 5350        모든면적
# 5351         60㎡
# 5352     60㎡~85㎡
# 5353    85㎡~102㎡
# 5354       102㎡~
# Name: 전용면적, Length: 5100, dtype: object

# %%
df_house.head()
# Out:
#     지역명               규모구분    연도  월 분양가격(㎡)    분양가격   평당분양가격      전용면적
# 255  서울               모든면적  2016  1    6108  6108.0  20156.4      모든면적
# 256  서울         전용면적 60㎡이하  2016  1    6427  6427.0  21209.1       60㎡
# 257  서울   전용면적 60㎡초과 85㎡이하  2016  1    6036  6036.0  19918.8   60㎡~85㎡
# 258  서울  전용면적 85㎡초과 102㎡이하  2016  1    6513  6513.0  21492.9  85㎡~102㎡
# 259  서울        전용면적 102㎡초과  2016  1    6551  6551.0  21618.3     102㎡~

# %% [markdown]
# #### 필요없는 컬럼 제거

# %%
df_house = df_house.drop(['규모구분','분양가격(㎡)'],axis=1)
df_house
# Out:
#      지역명    연도   월    분양가격   평당분양가격      전용면적
# 255   서울  2016   1  6108.0  20156.4      모든면적
# 256   서울  2016   1  6427.0  21209.1       60㎡
# 257   서울  2016   1  6036.0  19918.8   60㎡~85㎡
# 258   서울  2016   1  6513.0  21492.9  85㎡~102㎡
# 259   서울  2016   1  6551.0  21618.3     102㎡~
# ...   ..   ...  ..     ...      ...       ...
# 5350  제주  2020  12  4648.0  15338.4      모든면적
# 5351  제주  2020  12  4363.0  14397.9       60㎡
# 5352  제주  2020  12  4660.0  15378.0   60㎡~85㎡
# 5353  제주  2020  12     NaN      NaN  85㎡~102㎡
# 5354  제주  2020  12     NaN      NaN     102㎡~
#
# [5100 rows x 6 columns]

# %%
df_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5100 entries, 255 to 5354
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역명     5100 non-null   object
#  1   연도      5100 non-null   int64
#  2   월       5100 non-null   int64
#  3   분양가격    4596 non-null   float64
#  4   평당분양가격  4596 non-null   float64
#  5   전용면적    5100 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 278.9+ KB

# %%
df_house.groupby(['전용면적','지역명'])['분양가격'].mean()
# Out:
# 전용면적   지역명
# 102㎡~  강원     2848.288136
#        경기     4587.813559
#        경남     3134.269231
#        경북     2848.196429
#        광주     3606.857143
#                  ...
# 모든면적   전남     2309.135593
#        전북     2282.101695
#        제주     3551.745763
#        충남     2443.220339
#        충북     2242.067797
# Name: 분양가격, Length: 85, dtype: float64

# %%
korea = df_house['지역명'].unique()
korea
# Out:
# array(['서울', '인천', '경기', '부산', '대구', '광주', '대전', '울산', '세종', '강원', '충북',
#        '충남', '전북', '전남', '경북', '경남', '제주'], dtype=object)

# %%
for i in korea:
    j = df_house[df_house['지역명'] == i].copy()
    print(i,' 지역 널 갯수는 :', end=' ')
    print(j['분양가격'].isnull().sum(),'\n')
# Out:
# 서울  지역 널 갯수는 : 5
#
# 인천  지역 널 갯수는 : 9
#
# 경기  지역 널 갯수는 : 5
#
# 부산  지역 널 갯수는 : 5
#
# 대구  지역 널 갯수는 : 13
#
# 광주  지역 널 갯수는 : 52
#
# 대전  지역 널 갯수는 : 76
#
# 울산  지역 널 갯수는 : 122
#
# 세종  지역 널 갯수는 : 60
#
# 강원  지역 널 갯수는 : 17
#
# 충북  지역 널 갯수는 : 7
#
# 충남  지역 널 갯수는 : 21
#
# 전북  지역 널 갯수는 : 7
#
# 전남  지역 널 갯수는 : 11
#
# 경북  지역 널 갯수는 : 26
#
# 경남  지역 널 갯수는 : 14
#
# 제주  지역 널 갯수는 : 54

# %% [markdown]
# #### 위에서 널값이 20개 이하인 지역만 가져와서 전처리 할예정 집값의 기준을 마음대로 설정할수 없어 널값 최대한 줄이기 위함

# %%
for i in korea:
    j = df_house[df_house['지역명'] == i].copy()
    if j['분양가격'].isnull().sum() <= 20:
        print(i,' 지역 널 갯수는 :', end=' ')
        print(j['분양가격'].isnull().sum(),'\n')
# Out:
# 서울  지역 널 갯수는 : 5
#
# 인천  지역 널 갯수는 : 9
#
# 경기  지역 널 갯수는 : 5
#
# 부산  지역 널 갯수는 : 5
#
# 대구  지역 널 갯수는 : 13
#
# 강원  지역 널 갯수는 : 17
#
# 충북  지역 널 갯수는 : 7
#
# 전북  지역 널 갯수는 : 7
#
# 전남  지역 널 갯수는 : 11
#
# 경남  지역 널 갯수는 : 14

# %%
df_house_dosi = df_house.loc[(df_house['지역명'] == '서울') | (df_house['지역명'] == '인천') |
                             (df_house['지역명'] == '경기') | (df_house['지역명'] == '부산') |
                             (df_house['지역명'] == '대구') | (df_house['지역명'] == '강원') |
                             (df_house['지역명'] == '충북') | (df_house['지역명'] == '전북') |
                             (df_house['지역명'] == '전남') | (df_house['지역명'] == '경남') ].copy()

# %%
df_house_dosi.isnull().sum()
# Out:
# 지역명        0
# 연도         0
# 월          0
# 분양가격      93
# 평당분양가격    93
# 전용면적       0
# dtype: int64

# %%
df_house_dosi.index
# Out:
# Int64Index([ 255,  256,  257,  258,  259,  260,  261,  262,  263,  264,
#             ...
#             5335, 5336, 5337, 5338, 5339, 5345, 5346, 5347, 5348, 5349],
#            dtype='int64', length=3000)

# %%
df_house_dosi.head()
# Out:
#     지역명    연도  월    분양가격   평당분양가격      전용면적
# 255  서울  2016  1  6108.0  20156.4      모든면적
# 256  서울  2016  1  6427.0  21209.1       60㎡
# 257  서울  2016  1  6036.0  19918.8   60㎡~85㎡
# 258  서울  2016  1  6513.0  21492.9  85㎡~102㎡
# 259  서울  2016  1  6551.0  21618.3     102㎡~

# %% [markdown]
# #### 분양가격은 평당분양가격으로 처리해줘서 필요없음

# %%
df_house_dosi = df_house_dosi.drop('분양가격',axis = 1).copy()

# %%
df_house_dosi
# Out:
#      지역명    연도   월   평당분양가격      전용면적
# 255   서울  2016   1  20156.4      모든면적
# 256   서울  2016   1  21209.1       60㎡
# 257   서울  2016   1  19918.8   60㎡~85㎡
# 258   서울  2016   1  21492.9  85㎡~102㎡
# 259   서울  2016   1  21618.3     102㎡~
# ...   ..   ...  ..      ...       ...
# 5345  경남  2020  12   9860.4      모든면적
# 5346  경남  2020  12   9702.0       60㎡
# 5347  경남  2020  12   9810.9   60㎡~85㎡
# 5348  경남  2020  12  15576.0  85㎡~102㎡
# 5349  경남  2020  12  10447.8     102㎡~
#
# [3000 rows x 5 columns]

# %% [markdown]
# #### 모든 면적값은 어짜피 다른 전용면적에서 다 처리해줘서 필요없다고 판단하여 제거

# %%
df_house_dosi = df_house_dosi[df_house_dosi['전용면적'] != '모든면적'].copy()
df_house_dosi
# Out:
#      지역명    연도   월   평당분양가격      전용면적
# 256   서울  2016   1  21209.1       60㎡
# 257   서울  2016   1  19918.8   60㎡~85㎡
# 258   서울  2016   1  21492.9  85㎡~102㎡
# 259   서울  2016   1  21618.3     102㎡~
# 261   인천  2016   1  10982.4       60㎡
# ...   ..   ...  ..      ...       ...
# 5339  전남  2020  12  10929.6     102㎡~
# 5346  경남  2020  12   9702.0       60㎡
# 5347  경남  2020  12   9810.9   60㎡~85㎡
# 5348  경남  2020  12  15576.0  85㎡~102㎡
# 5349  경남  2020  12  10447.8     102㎡~
#
# [2400 rows x 5 columns]

# %% [markdown]
# #### 지역별로 나누어서 평당분양가격 전처리 할 예정

# %% [markdown]
# #### 서울

# %%
def null_preprocessing(df_house):
    for i in df_house[df_house['평당분양가격'].isnull()].index:
        df_house['평당분양가격'][i] = df_house['평당분양가격'][i+4] - (df_house['평당분양가격'][i+8] - df_house['평당분양가격'][i+4])

# %%
df_house_seoul = df_house_dosi[df_house_dosi['지역명'] == '서울'].copy()
df_house_seoul.head()
# Out:
#     지역명    연도  월   평당분양가격      전용면적
# 256  서울  2016  1  21209.1       60㎡
# 257  서울  2016  1  19918.8   60㎡~85㎡
# 258  서울  2016  1  21492.9  85㎡~102㎡
# 259  서울  2016  1  21618.3     102㎡~
# 341  서울  2016  2  21245.4       60㎡

# %%
df_house_seoul = df_house_seoul.reset_index()
df_house_seoul
# Out:
#      index 지역명    연도   월   평당분양가격      전용면적
# 0      256  서울  2016   1  21209.1       60㎡
# 1      257  서울  2016   1  19918.8   60㎡~85㎡
# 2      258  서울  2016   1  21492.9  85㎡~102㎡
# 3      259  서울  2016   1  21618.3     102㎡~
# 4      341  서울  2016   2  21245.4       60㎡
# ..     ...  ..   ...  ..      ...       ...
# 235   5189  서울  2020  11  28634.1     102㎡~
# 236   5271  서울  2020  12  28680.3       60㎡
# 237   5272  서울  2020  12  26043.6   60㎡~85㎡
# 238   5273  서울  2020  12  32237.7  85㎡~102㎡
# 239   5274  서울  2020  12  31287.3     102㎡~
#
# [240 rows x 6 columns]

# %%
df_house_seoul = df_house_seoul.reset_index()
df_house_seoul
# Out:
#      level_0  index 지역명    연도   월   평당분양가격      전용면적
# 0          0    256  서울  2016   1  21209.1       60㎡
# 1          1    257  서울  2016   1  19918.8   60㎡~85㎡
# 2          2    258  서울  2016   1  21492.9  85㎡~102㎡
# 3          3    259  서울  2016   1  21618.3     102㎡~
# 4          4    341  서울  2016   2  21245.4       60㎡
# ..       ...    ...  ..   ...  ..      ...       ...
# 235      235   5189  서울  2020  11  28634.1     102㎡~
# 236      236   5271  서울  2020  12  28680.3       60㎡
# 237      237   5272  서울  2020  12  26043.6   60㎡~85㎡
# 238      238   5273  서울  2020  12  32237.7  85㎡~102㎡
# 239      239   5274  서울  2020  12  31287.3     102㎡~
#
# [240 rows x 7 columns]

# %%
df_house_seoul = df_house_seoul.drop('index',axis = 1).copy()

# %%
df_house_seoul.rename(columns = {'level_0' : 'index'}, inplace = True)

# %%
df_house_seoul
# Out:
#      index 지역명    연도   월   평당분양가격      전용면적
# 0        0  서울  2016   1  21209.1       60㎡
# 1        1  서울  2016   1  19918.8   60㎡~85㎡
# 2        2  서울  2016   1  21492.9  85㎡~102㎡
# 3        3  서울  2016   1  21618.3     102㎡~
# 4        4  서울  2016   2  21245.4       60㎡
# ..     ...  ..   ...  ..      ...       ...
# 235    235  서울  2020  11  28634.1     102㎡~
# 236    236  서울  2020  12  28680.3       60㎡
# 237    237  서울  2020  12  26043.6   60㎡~85㎡
# 238    238  서울  2020  12  32237.7  85㎡~102㎡
# 239    239  서울  2020  12  31287.3     102㎡~
#
# [240 rows x 6 columns]

# %%
df_house_seoul[df_house_seoul['평당분양가격'].isnull()].index
# Out:
# Int64Index([88, 89, 90, 91], dtype='int64')

# %%
# df_house_seoul[df_house_seoul['index'] == 0]['평당분양가격']
df_house_seoul[df_house_seoul['index'] == 0]
# Out:
#    index 지역명    연도  월   평당분양가격 전용면적
# 0      0  서울  2016  1  21209.1  60㎡

# %%
df_house_seoul['평당분양가격'][0] - df_house_seoul['평당분양가격'][4]
# Out:
# -36.29999999999927

# %% [markdown]
# #### 만약에 1월 값이 null이면 1월은 = 2월 - (3월 - 2월) 이렇게 판단한 이유는 상승값 빼면 된다 판단

# %%
null_preprocessing(df_house_seoul)
# Out:
# <ipython-input-30-fc36ecccb985>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house['평당분양가격'][i] = df_house['평당분양가격'][i+4] - (df_house['평당분양가격'][i+8] - df_house['평당분양가격'][i+4])

# %%
df_house_seoul.isnull().sum()
# Out:
# index     0
# 지역명       0
# 연도        0
# 월         0
# 평당분양가격    0
# 전용면적      0
# dtype: int64

# %% [markdown]
# #### 인천

# %%
df_house_incheon = df_house_dosi[df_house_dosi['지역명'] == '인천'].copy()
df_house_incheon.head()
# Out:
#     지역명    연도  월   평당분양가격      전용면적
# 261  인천  2016  1  10982.4       60㎡
# 262  인천  2016  1  10263.0   60㎡~85㎡
# 263  인천  2016  1  11698.5  85㎡~102㎡
# 264  인천  2016  1  11246.4     102㎡~
# 346  인천  2016  2  10982.4       60㎡

# %%
df_house_incheon = df_house_incheon.reset_index().reset_index()
df_house_incheon
# Out:
#      level_0  index 지역명    연도   월   평당분양가격      전용면적
# 0          0    261  인천  2016   1  10982.4       60㎡
# 1          1    262  인천  2016   1  10263.0   60㎡~85㎡
# 2          2    263  인천  2016   1  11698.5  85㎡~102㎡
# 3          3    264  인천  2016   1  11246.4     102㎡~
# 4          4    346  인천  2016   2  10982.4       60㎡
# ..       ...    ...  ..   ...  ..      ...       ...
# 235      235   5194  인천  2020  11  16120.5     102㎡~
# 236      236   5276  인천  2020  12  15543.0       60㎡
# 237      237   5277  인천  2020  12  15391.2   60㎡~85㎡
# 238      238   5278  인천  2020  12  16820.1  85㎡~102㎡
# 239      239   5279  인천  2020  12  16229.4     102㎡~
#
# [240 rows x 7 columns]

# %%
df_house_incheon = df_house_incheon.drop('index',axis = 1).copy()

# %%
df_house_incheon.rename(columns = {'level_0' : 'index'}, inplace = True)

# %%
df_house_incheon
# Out:
#      index 지역명    연도   월   평당분양가격      전용면적
# 0        0  인천  2016   1  10982.4       60㎡
# 1        1  인천  2016   1  10263.0   60㎡~85㎡
# 2        2  인천  2016   1  11698.5  85㎡~102㎡
# 3        3  인천  2016   1  11246.4     102㎡~
# 4        4  인천  2016   2  10982.4       60㎡
# ..     ...  ..   ...  ..      ...       ...
# 235    235  인천  2020  11  16120.5     102㎡~
# 236    236  인천  2020  12  15543.0       60㎡
# 237    237  인천  2020  12  15391.2   60㎡~85㎡
# 238    238  인천  2020  12  16820.1  85㎡~102㎡
# 239    239  인천  2020  12  16229.4     102㎡~
#
# [240 rows x 6 columns]

# %%
df_house_incheon[df_house_incheon['평당분양가격'].isnull()]
# Out:
#      index 지역명    연도   월  평당분양가격      전용면적
# 88      88  인천  2017  11     NaN       60㎡
# 89      89  인천  2017  11     NaN   60㎡~85㎡
# 90      90  인천  2017  11     NaN  85㎡~102㎡
# 91      91  인천  2017  11     NaN     102㎡~
# 119    119  인천  2018   6     NaN     102㎡~
# 123    123  인천  2018   7     NaN     102㎡~
# 127    127  인천  2018   8     NaN     102㎡~
# 131    131  인천  2018   9     NaN     102㎡~

# %% [markdown]
# #### null 값이 2017년은 11월달에 만 없으므로 똑같이 1월 값이 null이면 1월은 = 2월 - (3월 - 2월) 이렇게 판단한 이유는 상승값 빼면 된다 판단
# #### 2018년은 전용면적이 똑같은 것이 없음 그래서 그 이후 값을 들고 오면 에러가남
# #### 그래서 2018년은 역으로 1월이면 전년 12월 + (12월 - 11월) 이렇게 판단한 이유는 저번 상승값이라 비슷할거라 판단

# %%
for i in df_house_incheon[df_house_incheon['평당분양가격'].isnull()].index:
    if df_house_incheon['연도'][i] == 2017:
        df_house_incheon['평당분양가격'][i] = df_house_incheon['평당분양가격'][i+4] - (df_house_incheon['평당분양가격'][i+8] - df_house_incheon['평당분양가격'][i+4])
    
    if df_house_incheon['연도'][i] == 2018:
        df_house_incheon['평당분양가격'][i] = df_house_incheon['평당분양가격'][i-4] + (df_house_incheon['평당분양가격'][i-4] - df_house_incheon['평당분양가격'][i-8])
# Out:
# <ipython-input-48-1bae5c62255b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house_incheon['평당분양가격'][i] = df_house_incheon['평당분양가격'][i+4] - (df_house_incheon['평당분양가격'][i+8] - df_house_incheon['평당분양가격'][i+4])
# <ipython-input-48-1bae5c62255b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house_incheon['평당분양가격'][i] = df_house_incheon['평당분양가격'][i-4] + (df_house_incheon['평당분양가격'][i-4] - df_house_incheon['평당분양가격'][i-8])

# %%
df_house_incheon[df_house_incheon['평당분양가격'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, 지역명, 연도, 월, 평당분양가격, 전용면적]
# Index: []

# %% [markdown]
# #### 경기

# %%
df_house_gyeonggi = df_house_dosi[df_house_dosi['지역명'] == '경기'].copy()
df_house_gyeonggi.head()
# Out:
#     지역명    연도  월   평당분양가격      전용면적
# 266  경기  2016  1  10866.9       60㎡
# 267  경기  2016  1  10932.9   60㎡~85㎡
# 268  경기  2016  1  11385.0  85㎡~102㎡
# 269  경기  2016  1  12705.0     102㎡~
# 351  경기  2016  2  10870.2       60㎡

# %%
df_house_gyeonggi = df_house_gyeonggi.reset_index().reset_index()
df_house_gyeonggi
# Out:
#      level_0  index 지역명    연도   월   평당분양가격      전용면적
# 0          0    266  경기  2016   1  10866.9       60㎡
# 1          1    267  경기  2016   1  10932.9   60㎡~85㎡
# 2          2    268  경기  2016   1  11385.0  85㎡~102㎡
# 3          3    269  경기  2016   1  12705.0     102㎡~
# 4          4    351  경기  2016   2  10870.2       60㎡
# ..       ...    ...  ..   ...  ..      ...       ...
# 235      235   5199  경기  2020  11  17397.6     102㎡~
# 236      236   5281  경기  2020  12  13368.3       60㎡
# 237      237   5282  경기  2020  12  14529.9   60㎡~85㎡
# 238      238   5283  경기  2020  12  15213.0  85㎡~102㎡
# 239      239   5284  경기  2020  12  17754.0     102㎡~
#
# [240 rows x 7 columns]

# %%
df_house_gyeonggi = df_house_gyeonggi.drop('index',axis = 1).copy()

# %%
df_house_gyeonggi.rename(columns = {'level_0' : 'index'}, inplace = True)

# %%
df_house_gyeonggi
# Out:
#      index 지역명    연도   월   평당분양가격      전용면적
# 0        0  경기  2016   1  10866.9       60㎡
# 1        1  경기  2016   1  10932.9   60㎡~85㎡
# 2        2  경기  2016   1  11385.0  85㎡~102㎡
# 3        3  경기  2016   1  12705.0     102㎡~
# 4        4  경기  2016   2  10870.2       60㎡
# ..     ...  ..   ...  ..      ...       ...
# 235    235  경기  2020  11  17397.6     102㎡~
# 236    236  경기  2020  12  13368.3       60㎡
# 237    237  경기  2020  12  14529.9   60㎡~85㎡
# 238    238  경기  2020  12  15213.0  85㎡~102㎡
# 239    239  경기  2020  12  17754.0     102㎡~
#
# [240 rows x 6 columns]

# %%
df_house_gyeonggi[df_house_gyeonggi['평당분양가격'].isnull()]
# Out:
#     index 지역명    연도   월  평당분양가격      전용면적
# 88     88  경기  2017  11     NaN       60㎡
# 89     89  경기  2017  11     NaN   60㎡~85㎡
# 90     90  경기  2017  11     NaN  85㎡~102㎡
# 91     91  경기  2017  11     NaN     102㎡~

# %% [markdown]
# #### 만약에 1월 값이 null이면 1월은 = 2월 - (3월 - 2월) 이렇게 판단한 이유는 상승값 빼면 된다 판단

# %%
for i in df_house_gyeonggi[df_house_gyeonggi['평당분양가격'].isnull()].index:
    df_house_gyeonggi['평당분양가격'][i] = df_house_gyeonggi['평당분양가격'][i+4] - (df_house_gyeonggi['평당분양가격'][i+8] - df_house_gyeonggi['평당분양가격'][i+4])
# Out:
# <ipython-input-56-1ad176742a0a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house_gyeonggi['평당분양가격'][i] = df_house_gyeonggi['평당분양가격'][i+4] - (df_house_gyeonggi['평당분양가격'][i+8] - df_house_gyeonggi['평당분양가격'][i+4])

# %%
df_house_gyeonggi[df_house_gyeonggi['평당분양가격'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, 지역명, 연도, 월, 평당분양가격, 전용면적]
# Index: []

# %% [markdown]
# #### 부산

# %%
df_house_busan = df_house_dosi[df_house_dosi['지역명'] == '부산'].copy()
df_house_busan.head()
# Out:
#     지역명    연도  월   평당분양가격      전용면적
# 271  부산  2016  1   9738.3       60㎡
# 272  부산  2016  1  10088.1   60㎡~85㎡
# 273  부산  2016  1   9758.1  85㎡~102㎡
# 274  부산  2016  1  12579.6     102㎡~
# 356  부산  2016  2   9896.7       60㎡

# %%
df_house_busan = df_house_busan.reset_index().reset_index()
df_house_busan
# Out:
#      level_0  index 지역명    연도   월   평당분양가격      전용면적
# 0          0    271  부산  2016   1   9738.3       60㎡
# 1          1    272  부산  2016   1  10088.1   60㎡~85㎡
# 2          2    273  부산  2016   1   9758.1  85㎡~102㎡
# 3          3    274  부산  2016   1  12579.6     102㎡~
# 4          4    356  부산  2016   2   9896.7       60㎡
# ..       ...    ...  ..   ...  ..      ...       ...
# 235      235   5204  부산  2020  11  13025.1     102㎡~
# 236      236   5286  부산  2020  12  14166.9       60㎡
# 237      237   5287  부산  2020  12  13929.3   60㎡~85㎡
# 238      238   5288  부산  2020  12  12678.6  85㎡~102㎡
# 239      239   5289  부산  2020  12  13025.1     102㎡~
#
# [240 rows x 7 columns]

# %%
df_house_busan = df_house_busan.drop('index',axis = 1).copy()

# %%
df_house_busan.rename(columns = {'level_0' : 'index'}, inplace = True)

# %%
df_house_busan.head()
# Out:
#    index 지역명    연도  월   평당분양가격      전용면적
# 0      0  부산  2016  1   9738.3       60㎡
# 1      1  부산  2016  1  10088.1   60㎡~85㎡
# 2      2  부산  2016  1   9758.1  85㎡~102㎡
# 3      3  부산  2016  1  12579.6     102㎡~
# 4      4  부산  2016  2   9896.7       60㎡

# %%
df_house_busan[df_house_busan['평당분양가격'].isnull()]
# Out:
#     index 지역명    연도   월  평당분양가격      전용면적
# 88     88  부산  2017  11     NaN       60㎡
# 89     89  부산  2017  11     NaN   60㎡~85㎡
# 90     90  부산  2017  11     NaN  85㎡~102㎡
# 91     91  부산  2017  11     NaN     102㎡~

# %% [markdown]
# #### 만약에 1월 값이 null이면 1월은 = 2월 - (3월 - 2월) 이렇게 판단한 이유는 상승값 빼면 된다 판단

# %%
for i in df_house_busan[df_house_busan['평당분양가격'].isnull()].index:
    df_house_busan['평당분양가격'][i] = df_house_busan['평당분양가격'][i+4] - (df_house_busan['평당분양가격'][i+8] - df_house_busan['평당분양가격'][i+4])
# Out:
# <ipython-input-64-bd43b007c425>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house_busan['평당분양가격'][i] = df_house_busan['평당분양가격'][i+4] - (df_house_busan['평당분양가격'][i+8] - df_house_busan['평당분양가격'][i+4])

# %%
df_house_busan[df_house_busan['평당분양가격'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, 지역명, 연도, 월, 평당분양가격, 전용면적]
# Index: []

# %% [markdown]
# #### 대구

# %%
df_house_daegu = df_house_dosi[df_house_dosi['지역명'] == '대구'].copy()
df_house_daegu.head()
# Out:
#     지역명    연도  월   평당분양가격      전용면적
# 276  대구  2016  1  11025.3       60㎡
# 277  대구  2016  1  10239.9   60㎡~85㎡
# 278  대구  2016  1   8355.6  85㎡~102㎡
# 279  대구  2016  1   9051.9     102㎡~
# 361  대구  2016  2  11025.3       60㎡

# %%
df_house_daegu = df_house_daegu.reset_index().reset_index()
df_house_daegu
# Out:
#      level_0  index 지역명    연도   월   평당분양가격      전용면적
# 0          0    276  대구  2016   1  11025.3       60㎡
# 1          1    277  대구  2016   1  10239.9   60㎡~85㎡
# 2          2    278  대구  2016   1   8355.6  85㎡~102㎡
# 3          3    279  대구  2016   1   9051.9     102㎡~
# 4          4    361  대구  2016   2  11025.3       60㎡
# ..       ...    ...  ..   ...  ..      ...       ...
# 235      235   5209  대구  2020  11  16087.5     102㎡~
# 236      236   5291  대구  2020  12  15292.2       60㎡
# 237      237   5292  대구  2020  12  15358.2   60㎡~85㎡
# 238      238   5293  대구  2020  12  16061.1  85㎡~102㎡
# 239      239   5294  대구  2020  12  16094.1     102㎡~
#
# [240 rows x 7 columns]

# %%
df_house_daegu = df_house_daegu.drop('index',axis = 1).copy()

# %%
df_house_daegu.rename(columns = {'level_0' : 'index'}, inplace = True)

# %%
df_house_daegu.head()
# Out:
#    index 지역명    연도  월   평당분양가격      전용면적
# 0      0  대구  2016  1  11025.3       60㎡
# 1      1  대구  2016  1  10239.9   60㎡~85㎡
# 2      2  대구  2016  1   8355.6  85㎡~102㎡
# 3      3  대구  2016  1   9051.9     102㎡~
# 4      4  대구  2016  2  11025.3       60㎡

# %%
df_house_daegu[df_house_daegu['평당분양가격'].isnull()]
# Out:
#      index 지역명    연도   월  평당분양가격      전용면적
# 74      74  대구  2017   7     NaN  85㎡~102㎡
# 78      78  대구  2017   8     NaN  85㎡~102㎡
# 82      82  대구  2017   9     NaN  85㎡~102㎡
# 86      86  대구  2017  10     NaN  85㎡~102㎡
# 88      88  대구  2017  11     NaN       60㎡
# 89      89  대구  2017  11     NaN   60㎡~85㎡
# 90      90  대구  2017  11     NaN  85㎡~102㎡
# 91      91  대구  2017  11     NaN     102㎡~
# 94      94  대구  2017  12     NaN  85㎡~102㎡
# 98      98  대구  2018   1     NaN  85㎡~102㎡
# 102    102  대구  2018   2     NaN  85㎡~102㎡
# 106    106  대구  2018   3     NaN  85㎡~102㎡

# %% [markdown]
# #### null 값이 2017년은 11월달에 만 없으므로 똑같이 1월 값이 null이면 1월은 = 2월 - (3월 - 2월) 이렇게 판단한 이유는 상승값 빼면 된다 판단
# #### 2017년은 전용면적이 10월 전에는 똑같은 것이 없음 그래서 그 이후 값을 들고 오면 에러가남
# #### 그래서 2017년 10월 전 꺼는 역으로 1월이면 전년 12월 + (12월 - 11월) 이렇게 판단한 이유는 저번 상승값이라 비슷할거라 판단

# %%
for i in df_house_daegu[df_house_daegu['평당분양가격'].isnull()].index:
    if df_house_daegu['연도'][i] == 2017 and df_house_daegu['월'][i] <= 10:
        df_house_daegu['평당분양가격'][i] = df_house_daegu['평당분양가격'][i-4] + (df_house_daegu['평당분양가격'][i-4] - df_house_daegu['평당분양가격'][i-8])
# Out:
# <ipython-input-72-89316fc23c89>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house_daegu['평당분양가격'][i] = df_house_daegu['평당분양가격'][i-4] + (df_house_daegu['평당분양가격'][i-4] - df_house_daegu['평당분양가격'][i-8])

# %%
df_house_daegu[df_house_daegu['평당분양가격'].isnull()]
# Out:
#      index 지역명    연도   월  평당분양가격      전용면적
# 88      88  대구  2017  11     NaN       60㎡
# 89      89  대구  2017  11     NaN   60㎡~85㎡
# 90      90  대구  2017  11     NaN  85㎡~102㎡
# 91      91  대구  2017  11     NaN     102㎡~
# 94      94  대구  2017  12     NaN  85㎡~102㎡
# 98      98  대구  2018   1     NaN  85㎡~102㎡
# 102    102  대구  2018   2     NaN  85㎡~102㎡
# 106    106  대구  2018   3     NaN  85㎡~102㎡

# %% [markdown]
# #### 나머지 널값은 1월 값이 null이면 1월은 = 전년 12월 + (12월 - 11월) 이렇게 판단한 이유는 저번 상승값이라 비슷할거라 판단

# %%
for i in df_house_daegu[df_house_daegu['평당분양가격'].isnull()].index:
    df_house_daegu['평당분양가격'][i] = df_house_daegu['평당분양가격'][i-4] + (df_house_daegu['평당분양가격'][i-4] - df_house_daegu['평당분양가격'][i-8])
# Out:
# <ipython-input-74-9bcadb0cda61>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house_daegu['평당분양가격'][i] = df_house_daegu['평당분양가격'][i-4] + (df_house_daegu['평당분양가격'][i-4] - df_house_daegu['평당분양가격'][i-8])

# %%
df_house_daegu[df_house_daegu['평당분양가격'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, 지역명, 연도, 월, 평당분양가격, 전용면적]
# Index: []

# %% [markdown]
# #### 강원

# %%
df_house_gangwon = df_house_dosi[df_house_dosi['지역명'] == '강원'].copy()
df_house_gangwon.head()
# Out:
#     지역명    연도  월  평당분양가격      전용면적
# 301  강원  2016  1  7557.0       60㎡
# 302  강원  2016  1  7256.7   60㎡~85㎡
# 303  강원  2016  1  6801.3  85㎡~102㎡
# 304  강원  2016  1  7164.3     102㎡~
# 386  강원  2016  2  7557.0       60㎡

# %%
df_house_gangwon = df_house_gangwon.reset_index().reset_index()
df_house_gangwon
# Out:
#      level_0  index 지역명    연도   월   평당분양가격      전용면적
# 0          0    301  강원  2016   1   7557.0       60㎡
# 1          1    302  강원  2016   1   7256.7   60㎡~85㎡
# 2          2    303  강원  2016   1   6801.3  85㎡~102㎡
# 3          3    304  강원  2016   1   7164.3     102㎡~
# 4          4    386  강원  2016   2   7557.0       60㎡
# ..       ...    ...  ..   ...  ..      ...       ...
# 235      235   5234  강원  2020  11  12988.8     102㎡~
# 236      236   5316  강원  2020  12  11837.1       60㎡
# 237      237   5317  강원  2020  12  10048.5   60㎡~85㎡
# 238      238   5318  강원  2020  12   9504.0  85㎡~102㎡
# 239      239   5319  강원  2020  12  14100.9     102㎡~
#
# [240 rows x 7 columns]

# %%
df_house_gangwon = df_house_gangwon.drop('index',axis = 1).copy()

# %%
df_house_gangwon.rename(columns = {'level_0' : 'index'}, inplace = True)

# %%
df_house_gangwon.head()
# Out:
#    index 지역명    연도  월  평당분양가격      전용면적
# 0      0  강원  2016  1  7557.0       60㎡
# 1      1  강원  2016  1  7256.7   60㎡~85㎡
# 2      2  강원  2016  1  6801.3  85㎡~102㎡
# 3      3  강원  2016  1  7164.3     102㎡~
# 4      4  강원  2016  2  7557.0       60㎡

# %%
df_house_gangwon[df_house_gangwon['평당분양가격'].isnull()]
# Out:
#      index 지역명    연도   월  평당분양가격      전용면적
# 6        6  강원  2016   2     NaN  85㎡~102㎡
# 10      10  강원  2016   3     NaN  85㎡~102㎡
# 14      14  강원  2016   4     NaN  85㎡~102㎡
# 18      18  강원  2016   5     NaN  85㎡~102㎡
# 22      22  강원  2016   6     NaN  85㎡~102㎡
# 26      26  강원  2016   7     NaN  85㎡~102㎡
# 30      30  강원  2016   8     NaN  85㎡~102㎡
# 34      34  강원  2016   9     NaN  85㎡~102㎡
# 88      88  강원  2017  11     NaN       60㎡
# 89      89  강원  2017  11     NaN   60㎡~85㎡
# 90      90  강원  2017  11     NaN  85㎡~102㎡
# 91      91  강원  2017  11     NaN     102㎡~
# 202    202  강원  2020   3     NaN  85㎡~102㎡
# 206    206  강원  2020   4     NaN  85㎡~102㎡
# 210    210  강원  2020   5     NaN  85㎡~102㎡
# 214    214  강원  2020   6     NaN  85㎡~102㎡

# %% [markdown]
# #### 2016년 1월이 시작이라 2월 부터 9월 까지의 같은면적 null값은 비교대상을 다른 면적들의 상승값 평균을 더했다

# %%
for i in df_house_gangwon[df_house_gangwon['평당분양가격'].isnull()].index:
    if df_house_gangwon['연도'][i] == 2016 and df_house_gangwon['월'][i] <= 9:
        df_house_gangwon['평당분양가격'][i] = df_house_gangwon['평당분양가격'][i-4] + np.mean(((df_house_gangwon['평당분양가격'][i+5] - df_house_gangwon['평당분양가격'][i+1]),
                                                                                 (df_house_gangwon['평당분양가격'][i+5-2] - df_house_gangwon['평당분양가격'][i+1-2]),
                                                                                 (df_house_gangwon['평당분양가격'][i+5-3] - df_house_gangwon['평당분양가격'][i+1-3])))
# Out:
# <ipython-input-82-bb5d91e0d963>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house_gangwon['평당분양가격'][i] = df_house_gangwon['평당분양가격'][i-4] + np.mean(((df_house_gangwon['평당분양가격'][i+5] - df_house_gangwon['평당분양가격'][i+1]),

# %%
df_house_gangwon[df_house_gangwon['평당분양가격'].isnull()]
# Out:
#      index 지역명    연도   월  평당분양가격      전용면적
# 88      88  강원  2017  11     NaN       60㎡
# 89      89  강원  2017  11     NaN   60㎡~85㎡
# 90      90  강원  2017  11     NaN  85㎡~102㎡
# 91      91  강원  2017  11     NaN     102㎡~
# 202    202  강원  2020   3     NaN  85㎡~102㎡
# 206    206  강원  2020   4     NaN  85㎡~102㎡
# 210    210  강원  2020   5     NaN  85㎡~102㎡
# 214    214  강원  2020   6     NaN  85㎡~102㎡

# %% [markdown]
# #### 나머지 널값은 1월 값이 null이면 1월은 = 전년 12월 + (12월 - 11월) 이렇게 판단한 이유는 저번 상승값이라 비슷할거라 판단

# %%
for i in df_house_gangwon[df_house_gangwon['평당분양가격'].isnull()].index:
    df_house_gangwon['평당분양가격'][i] = df_house_gangwon['평당분양가격'][i-4] + (df_house_gangwon['평당분양가격'][i-4] - df_house_gangwon['평당분양가격'][i-8])
# Out:
# <ipython-input-84-f2ed2294e639>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house_gangwon['평당분양가격'][i] = df_house_gangwon['평당분양가격'][i-4] + (df_house_gangwon['평당분양가격'][i-4] - df_house_gangwon['평당분양가격'][i-8])

# %%
df_house_gangwon[df_house_gangwon['평당분양가격'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, 지역명, 연도, 월, 평당분양가격, 전용면적]
# Index: []

# %% [markdown]
# #### 충북

# %%
df_house_chungbuk = df_house_dosi[df_house_dosi['지역명'] == '충북'].copy()
df_house_chungbuk.head()
# Out:
#     지역명    연도  월  평당분양가격      전용면적
# 306  충북  2016  1  6441.6       60㎡
# 307  충북  2016  1  6669.3   60㎡~85㎡
# 308  충북  2016  1  7510.8  85㎡~102㎡
# 309  충북  2016  1  7461.3     102㎡~
# 391  충북  2016  2  6441.6       60㎡

# %%
df_house_chungbuk = df_house_chungbuk.reset_index().reset_index()
df_house_chungbuk
# Out:
#      level_0  index 지역명    연도   월  평당분양가격      전용면적
# 0          0    306  충북  2016   1  6441.6       60㎡
# 1          1    307  충북  2016   1  6669.3   60㎡~85㎡
# 2          2    308  충북  2016   1  7510.8  85㎡~102㎡
# 3          3    309  충북  2016   1  7461.3     102㎡~
# 4          4    391  충북  2016   2  6441.6       60㎡
# ..       ...    ...  ..   ...  ..     ...       ...
# 235      235   5239  충북  2020  11  9233.4     102㎡~
# 236      236   5321  충북  2020  12  8550.3       60㎡
# 237      237   5322  충북  2020  12  8596.5   60㎡~85㎡
# 238      238   5323  충북  2020  12  8929.8  85㎡~102㎡
# 239      239   5324  충북  2020  12  9230.1     102㎡~
#
# [240 rows x 7 columns]

# %%
df_house_chungbuk = df_house_chungbuk.drop('index',axis = 1).copy()

# %%
df_house_chungbuk.rename(columns = {'level_0' : 'index'}, inplace = True)

# %%
df_house_chungbuk.head()
# Out:
#    index 지역명    연도  월  평당분양가격      전용면적
# 0      0  충북  2016  1  6441.6       60㎡
# 1      1  충북  2016  1  6669.3   60㎡~85㎡
# 2      2  충북  2016  1  7510.8  85㎡~102㎡
# 3      3  충북  2016  1  7461.3     102㎡~
# 4      4  충북  2016  2  6441.6       60㎡

# %%
df_house_chungbuk[df_house_chungbuk['평당분양가격'].isnull()]
# Out:
#      index 지역명    연도   월  평당분양가격      전용면적
# 88      88  충북  2017  11     NaN       60㎡
# 89      89  충북  2017  11     NaN   60㎡~85㎡
# 90      90  충북  2017  11     NaN  85㎡~102㎡
# 91      91  충북  2017  11     NaN     102㎡~
# 230    230  충북  2020  10     NaN  85㎡~102㎡
# 234    234  충북  2020  11     NaN  85㎡~102㎡

# %% [markdown]
# #### 널값은 1월 값이 null이면 1월은 = 전년 12월 + (12월 - 11월) 이렇게 판단한 이유는 저번 상승값이라 비슷할거라 판단

# %%
for i in df_house_chungbuk[df_house_chungbuk['평당분양가격'].isnull()].index:
    df_house_chungbuk['평당분양가격'][i] = df_house_chungbuk['평당분양가격'][i-4] + (df_house_chungbuk['평당분양가격'][i-4] - df_house_chungbuk['평당분양가격'][i-8])
# Out:
# <ipython-input-92-33565ca43f79>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house_chungbuk['평당분양가격'][i] = df_house_chungbuk['평당분양가격'][i-4] + (df_house_chungbuk['평당분양가격'][i-4] - df_house_chungbuk['평당분양가격'][i-8])

# %%
df_house_chungbuk[df_house_chungbuk['평당분양가격'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, 지역명, 연도, 월, 평당분양가격, 전용면적]
# Index: []

# %% [markdown]
# #### 전북

# %%
df_house_jeonbuk = df_house_dosi[df_house_dosi['지역명'] == '전북'].copy()
df_house_jeonbuk.head()
# Out:
#     지역명    연도  월  평당분양가격      전용면적
# 316  전북  2016  1  6296.4       60㎡
# 317  전북  2016  1  6557.1   60㎡~85㎡
# 318  전북  2016  1  7844.1  85㎡~102㎡
# 319  전북  2016  1  7530.6     102㎡~
# 401  전북  2016  2  6296.4       60㎡

# %%
df_house_jeonbuk = df_house_jeonbuk.reset_index().reset_index()
df_house_jeonbuk
# Out:
#      level_0  index 지역명    연도   월  평당분양가격      전용면적
# 0          0    316  전북  2016   1  6296.4       60㎡
# 1          1    317  전북  2016   1  6557.1   60㎡~85㎡
# 2          2    318  전북  2016   1  7844.1  85㎡~102㎡
# 3          3    319  전북  2016   1  7530.6     102㎡~
# 4          4    401  전북  2016   2  6296.4       60㎡
# ..       ...    ...  ..   ...  ..     ...       ...
# 235      235   5249  전북  2020  11  8454.6     102㎡~
# 236      236   5331  전북  2020  12  8408.4       60㎡
# 237      237   5332  전북  2020  12  8718.6   60㎡~85㎡
# 238      238   5333  전북  2020  12  7949.7  85㎡~102㎡
# 239      239   5334  전북  2020  12  8629.5     102㎡~
#
# [240 rows x 7 columns]

# %%
df_house_jeonbuk = df_house_jeonbuk.drop('index',axis = 1).copy()

# %%
df_house_jeonbuk.rename(columns = {'level_0' : 'index'}, inplace = True)

# %%
df_house_jeonbuk.head()
# Out:
#    index 지역명    연도  월  평당분양가격      전용면적
# 0      0  전북  2016  1  6296.4       60㎡
# 1      1  전북  2016  1  6557.1   60㎡~85㎡
# 2      2  전북  2016  1  7844.1  85㎡~102㎡
# 3      3  전북  2016  1  7530.6     102㎡~
# 4      4  전북  2016  2  6296.4       60㎡

# %%
df_house_jeonbuk[df_house_jeonbuk['평당분양가격'].isnull()]
# Out:
#     index 지역명    연도   월  평당분양가격      전용면적
# 82     82  전북  2017   9     NaN  85㎡~102㎡
# 86     86  전북  2017  10     NaN  85㎡~102㎡
# 88     88  전북  2017  11     NaN       60㎡
# 89     89  전북  2017  11     NaN   60㎡~85㎡
# 90     90  전북  2017  11     NaN  85㎡~102㎡
# 91     91  전북  2017  11     NaN     102㎡~

# %% [markdown]
# #### 널값은 1월 값이 null이면 1월은 = 전년 12월 + (12월 - 11월) 이렇게 판단한 이유는 저번 상승값이라 비슷할거라 판단¶

# %%
for i in df_house_jeonbuk[df_house_jeonbuk['평당분양가격'].isnull()].index:
    df_house_jeonbuk['평당분양가격'][i] = df_house_jeonbuk['평당분양가격'][i-4] + (df_house_jeonbuk['평당분양가격'][i-4] - df_house_jeonbuk['평당분양가격'][i-8])
# Out:
# <ipython-input-100-6961909fbd15>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house_jeonbuk['평당분양가격'][i] = df_house_jeonbuk['평당분양가격'][i-4] + (df_house_jeonbuk['평당분양가격'][i-4] - df_house_jeonbuk['평당분양가격'][i-8])

# %%
df_house_jeonbuk[df_house_jeonbuk['평당분양가격'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, 지역명, 연도, 월, 평당분양가격, 전용면적]
# Index: []

# %% [markdown]
# #### 전남

# %%
df_house_jeonnam = df_house_dosi[df_house_dosi['지역명'] == '전남'].copy()
df_house_jeonnam.head()
# Out:
#     지역명    연도  월  평당분양가격      전용면적
# 321  전남  2016  1  6596.7       60㎡
# 322  전남  2016  1  6289.8   60㎡~85㎡
# 323  전남  2016  1  7464.6  85㎡~102㎡
# 324  전남  2016  1  7180.8     102㎡~
# 406  전남  2016  2  6596.7       60㎡

# %%
df_house_jeonnam = df_house_jeonnam.reset_index().reset_index()
df_house_jeonnam
# Out:
#      level_0  index 지역명    연도   월   평당분양가격      전용면적
# 0          0    321  전남  2016   1   6596.7       60㎡
# 1          1    322  전남  2016   1   6289.8   60㎡~85㎡
# 2          2    323  전남  2016   1   7464.6  85㎡~102㎡
# 3          3    324  전남  2016   1   7180.8     102㎡~
# 4          4    406  전남  2016   2   6596.7       60㎡
# ..       ...    ...  ..   ...  ..      ...       ...
# 235      235   5254  전남  2020  11  11837.1     102㎡~
# 236      236   5336  전남  2020  12   8778.0       60㎡
# 237      237   5337  전남  2020  12   9345.6   60㎡~85㎡
# 238      238   5338  전남  2020  12   9969.3  85㎡~102㎡
# 239      239   5339  전남  2020  12  10929.6     102㎡~
#
# [240 rows x 7 columns]

# %%
df_house_jeonnam = df_house_jeonnam.drop('index',axis = 1).copy()

# %%
df_house_jeonnam.rename(columns = {'level_0' : 'index'}, inplace = True)

# %%
df_house_jeonnam.head()
# Out:
#    index 지역명    연도  월  평당분양가격      전용면적
# 0      0  전남  2016  1  6596.7       60㎡
# 1      1  전남  2016  1  6289.8   60㎡~85㎡
# 2      2  전남  2016  1  7464.6  85㎡~102㎡
# 3      3  전남  2016  1  7180.8     102㎡~
# 4      4  전남  2016  2  6596.7       60㎡

# %%
df_house_jeonnam[df_house_jeonnam['평당분양가격'].isnull()]
# Out:
#      index 지역명    연도   월  평당분양가격      전용면적
# 88      88  전남  2017  11     NaN       60㎡
# 89      89  전남  2017  11     NaN   60㎡~85㎡
# 90      90  전남  2017  11     NaN  85㎡~102㎡
# 91      91  전남  2017  11     NaN     102㎡~
# 186    186  전남  2019  11     NaN  85㎡~102㎡
# 190    190  전남  2019  12     NaN  85㎡~102㎡
# 194    194  전남  2020   1     NaN  85㎡~102㎡
# 198    198  전남  2020   2     NaN  85㎡~102㎡
# 220    220  전남  2020   8     NaN       60㎡
# 224    224  전남  2020   9     NaN       60㎡

# %% [markdown]
# #### 널값은 1월 값이 null이면 1월은 = 전년 12월 + (12월 - 11월) 이렇게 판단한 이유는 저번 상승값이라 비슷할거라 판단

# %%
for i in df_house_jeonnam[df_house_jeonnam['평당분양가격'].isnull()].index:
    df_house_jeonnam['평당분양가격'][i] = df_house_jeonnam['평당분양가격'][i-4] + (df_house_jeonnam['평당분양가격'][i-4] - df_house_jeonnam['평당분양가격'][i-8])
# Out:
# <ipython-input-108-5a7836eab959>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house_jeonnam['평당분양가격'][i] = df_house_jeonnam['평당분양가격'][i-4] + (df_house_jeonnam['평당분양가격'][i-4] - df_house_jeonnam['평당분양가격'][i-8])

# %%
df_house_jeonnam[df_house_jeonnam['평당분양가격'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, 지역명, 연도, 월, 평당분양가격, 전용면적]
# Index: []

# %% [markdown]
# #### 경남

# %%
df_house_gyeongnam = df_house_dosi[df_house_dosi['지역명'] == '경남'].copy()
df_house_gyeongnam.head()
# Out:
#     지역명    연도  월  평당분양가격      전용면적
# 331  경남  2016  1  7491.0       60㎡
# 332  경남  2016  1  7748.4   60㎡~85㎡
# 333  경남  2016  1  9652.5  85㎡~102㎡
# 334  경남  2016  1  9332.4     102㎡~
# 416  경남  2016  2  7791.3       60㎡

# %%
df_house_gyeongnam = df_house_gyeongnam.reset_index().reset_index()
df_house_gyeongnam
# Out:
#      level_0  index 지역명    연도   월   평당분양가격      전용면적
# 0          0    331  경남  2016   1   7491.0       60㎡
# 1          1    332  경남  2016   1   7748.4   60㎡~85㎡
# 2          2    333  경남  2016   1   9652.5  85㎡~102㎡
# 3          3    334  경남  2016   1   9332.4     102㎡~
# 4          4    416  경남  2016   2   7791.3       60㎡
# ..       ...    ...  ..   ...  ..      ...       ...
# 235      235   5264  경남  2020  11  10447.8     102㎡~
# 236      236   5346  경남  2020  12   9702.0       60㎡
# 237      237   5347  경남  2020  12   9810.9   60㎡~85㎡
# 238      238   5348  경남  2020  12  15576.0  85㎡~102㎡
# 239      239   5349  경남  2020  12  10447.8     102㎡~
#
# [240 rows x 7 columns]

# %%
df_house_gyeongnam = df_house_gyeongnam.drop('index',axis = 1).copy()

# %%
df_house_gyeongnam.rename(columns = {'level_0' : 'index'}, inplace = True)

# %%
df_house_gyeongnam.head()
# Out:
#    index 지역명    연도  월  평당분양가격      전용면적
# 0      0  경남  2016  1  7491.0       60㎡
# 1      1  경남  2016  1  7748.4   60㎡~85㎡
# 2      2  경남  2016  1  9652.5  85㎡~102㎡
# 3      3  경남  2016  1  9332.4     102㎡~
# 4      4  경남  2016  2  7791.3       60㎡

# %%
df_house_gyeongnam[df_house_gyeongnam['평당분양가격'].isnull()]
# Out:
#      index 지역명    연도   월  평당분양가격      전용면적
# 88      88  경남  2017  11     NaN       60㎡
# 89      89  경남  2017  11     NaN   60㎡~85㎡
# 90      90  경남  2017  11     NaN  85㎡~102㎡
# 91      91  경남  2017  11     NaN     102㎡~
# 176    176  경남  2019   9     NaN       60㎡
# 180    180  경남  2019  10     NaN       60㎡
# 191    191  경남  2019  12     NaN     102㎡~
# 195    195  경남  2020   1     NaN     102㎡~
# 199    199  경남  2020   2     NaN     102㎡~
# 203    203  경남  2020   3     NaN     102㎡~
# 207    207  경남  2020   4     NaN     102㎡~
# 211    211  경남  2020   5     NaN     102㎡~
# 215    215  경남  2020   6     NaN     102㎡~

# %% [markdown]
# #### 널값은 1월 값이 null이면 1월은 = 전년 12월 + (12월 - 11월) 이렇게 판단한 이유는 저번 상승값이라 비슷할거라 판단

# %%
for i in df_house_gyeongnam[df_house_gyeongnam['평당분양가격'].isnull()].index:
    df_house_gyeongnam['평당분양가격'][i] = df_house_gyeongnam['평당분양가격'][i-4] + (df_house_gyeongnam['평당분양가격'][i-4] - df_house_gyeongnam['평당분양가격'][i-8])
# Out:
# <ipython-input-116-104b295aa692>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_house_gyeongnam['평당분양가격'][i] = df_house_gyeongnam['평당분양가격'][i-4] + (df_house_gyeongnam['평당분양가격'][i-4] - df_house_gyeongnam['평당분양가격'][i-8])

# %%
df_house_gyeongnam[df_house_gyeongnam['평당분양가격'].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, 지역명, 연도, 월, 평당분양가격, 전용면적]
# Index: []

# %%
df_house_gu = pd.concat([df_house_seoul, df_house_gyeonggi, df_house_busan, df_house_daegu,
                        df_house_gangwon, df_house_chungbuk, df_house_jeonbuk, df_house_jeonnam,
                        df_house_gyeongnam], axis = 0)

# %%
df_house_gu.head()
# Out:
#    index 지역명    연도  월   평당분양가격      전용면적
# 0      0  서울  2016  1  21209.1       60㎡
# 1      1  서울  2016  1  19918.8   60㎡~85㎡
# 2      2  서울  2016  1  21492.9  85㎡~102㎡
# 3      3  서울  2016  1  21618.3     102㎡~
# 4      4  서울  2016  2  21245.4       60㎡

# %%
df_house_gu.isnull().sum()
# Out:
# index     0
# 지역명       0
# 연도        0
# 월         0
# 평당분양가격    0
# 전용면적      0
# dtype: int64

# %% [markdown]
# #### 전처리한 파일 엑셀로 저장

# %%
# df_house_gu.to_csv('house.csv', index=False, encoding='cp949')

# %%
df_house_dosi = pd.read_csv("house.csv",encoding='cp949')
df_house_dosi
# Out:
#       index 지역명    연도   월   평당분양가격      전용면적
# 0         0  서울  2016   1  21209.1       60㎡
# 1         1  서울  2016   1  19918.8   60㎡~85㎡
# 2         2  서울  2016   1  21492.9  85㎡~102㎡
# 3         3  서울  2016   1  21618.3     102㎡~
# 4         4  서울  2016   2  21245.4       60㎡
# ...     ...  ..   ...  ..      ...       ...
# 2155    235  경남  2020  11  10447.8     102㎡~
# 2156    236  경남  2020  12   9702.0       60㎡
# 2157    237  경남  2020  12   9810.9   60㎡~85㎡
# 2158    238  경남  2020  12  15576.0  85㎡~102㎡
# 2159    239  경남  2020  12  10447.8     102㎡~
#
# [2160 rows x 6 columns]

# %%
df_house_dosi = df_house_dosi.drop('index',axis = 1).copy()

# %%
df_house_dosi.head()
# Out:
#   지역명    연도  월   평당분양가격      전용면적
# 0  서울  2016  1  21209.1       60㎡
# 1  서울  2016  1  19918.8   60㎡~85㎡
# 2  서울  2016  1  21492.9  85㎡~102㎡
# 3  서울  2016  1  21618.3     102㎡~
# 4  서울  2016  2  21245.4       60㎡

# %%
df_house_dosi.isnull().sum()
# Out:
# 지역명       0
# 연도        0
# 월         0
# 평당분양가격    0
# 전용면적      0
# dtype: int64

# %% [markdown]
# #### 지도에서 보기위한 경도 위도 처리

# %%
df_house_dosi.loc[df_house_dosi['지역명'].str.contains('서울'),'경도'] = 126.97833527595007

# %% [markdown]
# #### 처리된거 확인

# %%
df_house_dosi[df_house_dosi['지역명']=='서울'].head()
# Out:
#   지역명    연도  월   평당분양가격      전용면적          경도
# 0  서울  2016  1  21209.1       60㎡  126.978335
# 1  서울  2016  1  19918.8   60㎡~85㎡  126.978335
# 2  서울  2016  1  21492.9  85㎡~102㎡  126.978335
# 3  서울  2016  1  21618.3     102㎡~  126.978335
# 4  서울  2016  2  21245.4       60㎡  126.978335

# %%
df_house_dosi['지역명'].unique()
# Out:
# array(['서울', '경기', '부산', '대구', '강원', '충북', '전북', '전남', '경남'], dtype=object)

# %%
df_house_dosi.loc[df_house_dosi['지역명'].str.contains('서울'),'위도'] = 37.56666950126609

df_house_dosi.loc[df_house_dosi['지역명'].str.contains('경기'),'위도'] = 37.274906479858764
df_house_dosi.loc[df_house_dosi['지역명'].str.contains('경기'),'경도'] = 127.00921653805827

df_house_dosi.loc[df_house_dosi['지역명'].str.contains('부산'),'위도'] = 35.17974743433661
df_house_dosi.loc[df_house_dosi['지역명'].str.contains('부산'),'경도'] = 129.07502991248603

df_house_dosi.loc[df_house_dosi['지역명'].str.contains('대구'),'위도'] = 35.87138392116897
df_house_dosi.loc[df_house_dosi['지역명'].str.contains('대구'),'경도'] = 128.60176122335534

df_house_dosi.loc[df_house_dosi['지역명'].str.contains('강원'),'위도'] = 37.88533303351936
df_house_dosi.loc[df_house_dosi['지역명'].str.contains('강원'),'경도'] = 127.7298086355599

df_house_dosi.loc[df_house_dosi['지역명'].str.contains('충북'),'위도'] = 36.635633006337365
df_house_dosi.loc[df_house_dosi['지역명'].str.contains('충북'),'경도'] = 127.49137384332671

df_house_dosi.loc[df_house_dosi['지역명'].str.contains('전북'),'위도'] = 35.82029494433091
df_house_dosi.loc[df_house_dosi['지역명'].str.contains('전북'),'경도'] = 127.10878586567907

df_house_dosi.loc[df_house_dosi['지역명'].str.contains('전남'),'위도'] = 34.81611288144505
df_house_dosi.loc[df_house_dosi['지역명'].str.contains('전남'),'경도'] = 126.46292419713417

df_house_dosi.loc[df_house_dosi['지역명'].str.contains('경남'),'위도'] = 35.23826300945596 
df_house_dosi.loc[df_house_dosi['지역명'].str.contains('경남'),'경도'] = 128.6924318378324

# %%
#### 제대로 처리됬는지 확인

# %%
df_house_dosi['위도'].unique()
# Out:
# array([37.5666695 , 37.27490648, 35.17974743, 35.87138392, 37.88533303,
#        36.63563301, 35.82029494, 34.81611288, 35.23826301])

# %%
df_house_dosi_lat = df_house_dosi[(df_house_dosi['전용면적']=='102㎡~') & (df_house_dosi['연도'] == 2020) & (df_house_dosi['월'] == 12)]
df_house_dosi_lat
# Out:
#      지역명    연도   월   평당분양가격   전용면적          경도         위도
# 239   서울  2020  12  31287.3  102㎡~  126.978335  37.566670
# 479   경기  2020  12  17754.0  102㎡~  127.009217  37.274906
# 719   부산  2020  12  13025.1  102㎡~  129.075030  35.179747
# 959   대구  2020  12  16094.1  102㎡~  128.601761  35.871384
# 1199  강원  2020  12  14100.9  102㎡~  127.729809  37.885333
# 1439  충북  2020  12   9230.1  102㎡~  127.491374  36.635633
# 1679  전북  2020  12   8629.5  102㎡~  127.108786  35.820295
# 1919  전남  2020  12  10929.6  102㎡~  126.462924  34.816113
# 2159  경남  2020  12  10447.8  102㎡~  128.692432  35.238263

# %%
lat = df_house_dosi_lat['위도'].mean() # 초기 위도 초기화
long = df_house_dosi_lat['경도'].mean() # 초기 경도 초기화

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\apps\weekend_study\lib\site-packages (0.12.1)
# Requirement already satisfied: branca>=0.3.0 in c:\apps\weekend_study\lib\site-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2>=2.9 in c:\apps\weekend_study\lib\site-packages (from folium) (3.0.1)
# Requirement already satisfied: numpy in c:\apps\weekend_study\lib\site-packages (from folium) (1.21.0)
# Requirement already satisfied: requests in c:\apps\weekend_study\lib\site-packages (from folium) (2.25.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\apps\weekend_study\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\apps\weekend_study\lib\site-packages (from requests->folium) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in c:\apps\weekend_study\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\apps\weekend_study\lib\site-packages (from requests->folium) (1.26.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\apps\weekend_study\lib\site-packages (from requests->folium) (4.0.0)

# %%
import folium

# %%
m = folium.Map([lat,long],zoom_start=7) # 처음 화면 보일때 시작점과 크기,

for i in df_house_dosi_lat.index:
    sub_lat = df_house_dosi_lat.loc[i,'위도']
    sub_long = df_house_dosi_lat.loc[i,'경도']
    tooltip = df_house_dosi_lat.loc[i,'지역명'] + ' : ' + str(df_house_dosi_lat.loc[i,'평당분양가격']) + "천원" # 마우스 올릴떄 이벤트
    
    color = 'green'
    
    radius = df_house_dosi_lat.loc[i,'평당분양가격']/1000
    
    # fill = True 바꿔보며 실습
    folium.CircleMarker([sub_lat,sub_long],tooltip=tooltip,color=color,radius=radius, fill = True).add_to(m)

# m.save('index.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_38cdcbee9aaf4bf7bb3ede9f3dd3d30e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_38cdcbee9aaf4bf7bb3ede9f3dd3d30e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_38cdcbee9aaf4bf7bb3ede9f3dd3d30e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_38cdcbee9aaf4bf7bb3ede9f3dd3d30e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B36.2542604679688%2C%20127.68329636993134%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20 ...
